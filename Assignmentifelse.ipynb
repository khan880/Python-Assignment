# %%
#Q1-
unit=int(input('Enter the unit'))
price=float(input('Enter the price'))

# %%
#Q2-
user_marks=float(input('Enter the marks='))
if user_marks > 90:
    print("Grade A")
elif user_marks > 80 and user_marks <= 90:
    print("Grade B")
elif user_marks >= 60 and user_marks <= 80:
    print("Grade C")
else:
    print("Grade D")

# %%
#Q3-
sohan=int(input('sohan the Age='))
mohan=int(input('mohan the Age='))
sachin=int(input('sachin the Age='))
raju=int(input('raju the Age='))

if sohan<=mohan and sohan<=sachin and sohan<=raju:
    print("sohan youngest")
elif mohan<=sohan and mohan<=sachin and mohan<=raju:
    print("mohan youngest")
elif sachin<=sohan and sachin<=mohan and sachin<=raju:
    print("sachin youngest")
else:
    print("raju youngest")
# Out:
# sohan the Age= 60
# mohan the Age= 50
# sachin the Age= 56
# raju the Age= 18
# raju youngest

# %%
#Q4-
emp_salary = float(input("Enter employee salary="))
emp_years = int(input("Enter employee years of service="))

if emp_years > 10:
    emp_bonus = emp_salary * 0.10
    print(emp_bonus)
elif emp_years >= 6 and years <= 10:
    emp_bonus = emp_salary * 0.08
    print(emp_bonus)
else:
    emp_bonus = emp_salary * 0.05
    print(emp_bonus)
# Out:
# Enter employee salary= 40000
# Enter employee years of service= 15
# 4000.0

# %%
#Q5-
num1=int(input('Enter the first number='))
num2=int(input('Enter the Second number='))
num3=int(input('Enter the Third number='))

if (num1>=num2 and num1<=num3) or (num1<=num2 and num1<=num3):
    print("second_largest num1")
elif (num2>=num1 and num2<=num3) or (num2<=num1 and num2>=num3) :
    print("second_largest num2")
else:
    print("second_largest num3")
# Out:
# Enter the first number= 1
# Enter the Second number= 5
# Enter the Third number= 6
# second_largest num1

# %%
#Q6-
market_price = float(input("Enter Marked Price: "))

if mp > 10000:
    discount = market_price * 0.20
elif market_price > 7000 and market_price <= 10000:
    discount = market_price * 0.15
else:
    discount = market_price * 0.10

net_amount = mp - discount

print("Discount:", discount)
print("Net Amount to Pay:", net_amount)

# %%
#Q7-
english = int(input("Enter English marks: "))
math = int(input("Enter Math marks: "))
science = int(input("Enter Science marks: "))
social_studies = int(input("Enter Social Studies marks: "))

if english > 80 and math > 80 and science > 80 and social_studies > 80:
    print("Science Stream")
elif english > 80 and math > 50 and science > 50:
    print("Commerce Stream")
elif english > 80 and social_studies > 80:
    print("Humanities Stream")
else:
    print("No stream allotted")

# %%
#Q8-
num = int(input("Enter a number: "))

if num % 5 == 0:
    print("Hello")
else:
    print("Bye")

# %%
#Q9-
num = int(input("Enter a number: "))

last_digit = num % 10

if last_digit == 0:
    print("Last digit is divisible by 3")
elif last_digit % 3 == 0:
    print("Last digit is divisible by 3")
else:
    print("Last digit is not divisible by 3")
# Out:
# Enter a number:  11
# Last digit is not divisible by 3

# %%
#Q10-
num = int(input("Enter a number: "))

if num >= 100 and num <= 999:
    print("The number is a three-digit number.")
elif num <= -100 and num >= -999:
    print("The number is a three-digit number.")
else:
    print("The number is not a three-digit number.")
# Out:
# Enter a number:  100
# The number is a three-digit number.
