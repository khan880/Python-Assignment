# %%
#Q:Reverse the string using for loop
input_string="Python"
revesed_str=""
for char in input_string:
    revesed_str=revesed_str+char
print( revesed_str)

# %%
def reverse_string(input_string: str) -> str:
    
    if not isinstance(input_string,str):
        raise TypeError("Input must be a string")
    revesed_str=""
    for char in input_string:
        revesed_str=char+revesed_str
    return revesed_str 
if __name__ == "__main__":
        try:
            user_input=input("Enter your  string to reversel:")
            result=reverse_string(user_input)
            print(f"Reversed string:{result}")
        except TypeError as e:
            print(e)        
        except TypeError as e:
         print(e)
# Out:
# Enter your  string to reversel: python
# Reversed string:nohtyp

# %%
def reverse_string(input_string: str) -> str:
    """
funcation reverse a given string using for loop and if else loop.
Args:
    input_str(str):The string to reversed.
Returns:
    str:The revesed version of type input string.
Raises:
   TypeError: if input is not a string so show error that please input the correct string.
"""    
    if not isinstance(input_string,str):
        raise TypeError("Input must be a string")
    revesed_str=""
    for char in input_string:
        revesed_str=char+revesed_str
    return revesed_str 
if __name__ == "__main__":
        try:
            user_input=input("Enter your  string to reversel:")
            result=reverse_string(user_input)
            print(f"Reversed string:{result}")
        except TypeError as e:
            print(e)        
        except TypeError as e:
         print(e)
# Out:
# Enter your  string to reversel: education
# Reversed string:noitacude
