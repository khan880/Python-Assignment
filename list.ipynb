# %%
def my_funcation(num,num2):
    return f"hi your number is {num} and {num2}"
pr(my_funcation(12,16))
# Out:
# hi your number is 12 and 16

# %%
list1=[10,20,50]
list1.reverse()

# %%
list1=[100]
for item in range(1,11):
    list1.clear()
print(list1)
# Out:
# []

# %%
list1=[100]
for item in range(1,11):
    list1.copy()
print(list1)
# Out:
# [100]

# %%
list1=[100]
for item in range(1,11):
    list1.count(item)
print(list1)
# Out:
# [100]

# %%
list2=["sonu"]
list2.append(list2)
print(list2)
# Out:
# ['sonu', [...]]

# %%
list2=["sonu"]
list2.clear()
print(list2)
# Out:
# []

# %%
list1=[10,20,30]
list2=[40,50,60]
list1.append(list2)
print(list1)
# Out:
# [10, 20, 30, [40, 50, 60]]

# %%
list1=[10,20,30]
list2=[40,50,60]
list1.extend(list2)
print(list1)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 = [10, 20, 30, 20, 40, 20, 50]
result = list1.count(10)
print("10 appears", result, "times")
# Out:
# 10 appears 1 times

# %%
list1 = ["Ram", "Shyam", "Ram", "Amit", "Ram"]
result=list1.count("Ram")
print("Ram appears:",result ,"times")
# Out:
# Ram appears: 3 times

# %%
list1 = [10, 20, 30, 40]
list1.insert(2, 25)   
print(list1)
# Out:
# [10, 20, 25, 30, 40]

# %%
list1 = [100, 200, 300]
pos = int(input("Enter position: "))
value = int(input("Enter value: "))
list1.insert(pos, value)
print("Updated list:", list1)
# Out:
# Enter position:  2
# Enter value:  25
# Updated list: [100, 200, 25, 300]

# %%
names = ["Amit", "Ravi", "Suresh", "Ravi"]
print("Index of Ravi:", names.index("Ravi"))
# Out:
# Index of Ravi: 1

# %%
numbers = [10, 20, 30, 40,50]
removed = numbers.pop()
print("Removed element:", removed)
print("Updated list:", numbers)
# Out:
# Removed element: 50
# Updated list: [10, 20, 30, 40]

# %%
list1 = [40, 10, 30, 20, 50]
list1.sort()
print("Sorted list:", list1)
# Out:
# Sorted list: [10, 20, 30, 40, 50]

# %%
list1 = [40, 10, 30, 20]
list1.sort(reverse=True)
print("Descending order:", numbers)
# Out:
# Descending order: [10, 20, 30, 40]

# %%
list1 = [10, 20, 30, 40, 50]
list1.reverse()
print("Reversed list:", list1)
# Out:
# Reversed list: [50, 40, 30, 20, 10]

# %%
list1 = [10, 20, 30, 20, 40]
list1.remove(20)
print("Updated list:", list1)
# Out:
# Updated list: [10, 30, 20, 40]
